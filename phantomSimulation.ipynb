# %%
import numpy as np 
from matplotlib import pyplot

# %%
run prueba

# %%
run Funciones

# %%
#run Phantoms

# %%
size=256
energy=40
p=cube_phantom_cc(size, energy)
# Out:
# 0.285
# 1.28

# %%
slice_ccf= p[:,128,:]

# %%
pyplot.imshow(slice_ccf, cmap="gray")
pyplot.show()

# %%
nLine= 128
line= getLine(slice_ccf, nLine)
pyplot.plot(line)

# %%
# Lateral View
slice_ccl= p[:,:,128]
pyplot.imshow(slice_ccl, cmap='gray')
pyplot.show()

# %%
nLine= 128
line= getLine(slice_ccl, nLine)
pyplot.plot(line)

# %%
run prueba2

# %%
size=256
energy=40
p=cube_phantom_ccc(size, energy)
# Out:
# 0.000299
# 0.268
# 0.285

# %%
slice_cccf= p[:,128,:]

# %%
pyplot.imshow(slice_cccf, cmap="gray")
pyplot.show()

# %%
nLine= 128
line= getLine(slice_cccf, nLine)
pyplot.plot(line)

# %%
# Lateral View
slice_cccl= p[:,:,128]
pyplot.imshow(slice_cccl, cmap='gray')
pyplot.show()

# %%
nLine= 128
line= getLine(slice_cccl, nLine)
pyplot.plot(line)

# %%
run prueba3

# %%
size=256
energy=40
p=breast_phantom(size, energy)
# Out:
# 0.000299
# 0.228
# 0.258
# 0.285

# %%
slice_breastf= p[:,128,:]

# %%
pyplot.imshow(slice_breastf, cmap="gray")
pyplot.show()

# %%
nLine= 128
line= getLine(slice_breastf, nLine)
pyplot.plot(line)

# %%
# Lateral View
slice_breastf= p[:,:,75]

# %%
pyplot.imshow(slice_breastf, cmap="gray")
pyplot.show()

# %%
nLine= 128
line= getLine(slice_breastf, nLine)
pyplot.plot(line)

# %%
# Lateral View
slice_breastf= p[:,:,225]

# %%
pyplot.imshow(slice_breastf, cmap="gray")
pyplot.show()

# %%
nLine= 128
line= getLine(slice_breastf, nLine)
pyplot.plot(line)
